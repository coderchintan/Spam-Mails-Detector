# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/chintan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
set(stopwords.words('english'))
# Out:
# {u'a',
#  u'about',
#  u'above',
#  u'after',
#  u'again',
#  u'against',
#  u'ain',
#  u'all',
#  u'am',
#  u'an',
#  u'and',
#  u'any',
#  u'are',
#  u'aren',
#  u"aren't",
#  u'as',
#  u'at',
#  u'be',
#  u'because',
#  u'been',
#  u'before',
#  u'being',
#  u'below',
#  u'between',
#  u'both',
#  u'but',
#  u'by',
#  u'can',
#  u'couldn',
#  u"couldn't",
#  u'd',
#  u'did',
#  u'didn',
#  u"didn't",
#  u'do',
#  u'does',
#  u'doesn',
#  u"doesn't",
#  u'doing',
#  u'don',
#  u"don't",
#  u'down',
#  u'during',
#  u'each',
#  u'few',
#  u'for',
#  u'from',
#  u'further',
#  u'had',
#  u'hadn',
#  u"hadn't",
#  u'has',
#  u'hasn',
#  u"hasn't",
#  u'have',
#  u'haven',
#  u"haven't",
#  u'having',
#  u'he',
#  u'her',
#  u'here',
#  u'hers',
#  u'herself',
#  u'him',
#  u'himself',
#  u'his',
#  u'how',
#  u'i',
#  u'if',
#  u'in',
#  u'into',
#  u'is',
#  u'isn',
#  u"isn't",
#  u'it',
#  u"it's",
#  u'its',
#  u'itself',
#  u'just',
#  u'll',
#  u'm',
#  u'ma',
#  u'me',
# ...
